# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Source on Dataset
#
# [Global Data on Sustainable Energy - Ansh Tanwar](https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy)

# %%
df = pd.read_csv("database/global-data-on-sustainable-energy.csv")

# %%
display(df)
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
sampled_df = df.sample(n=500, random_state=42)

# %%
display(sampled_df)
# Out:
#                Entity  Year  Access to electricity (% of population)  \
# 1406           Guinea  2019                                42.200000
# 3598            Yemen  2012                                52.410000
# 3646         Zimbabwe  2018                                45.572647
# 3230       Tajikistan  2001                                98.633100
# 3114            Spain  2011                               100.000000
# ...               ...   ...                                      ...
# 700             Chile  2007                                98.092020
# 2457  North Macedonia  2006                                99.000000
# 1298          Germany  2016                               100.000000
# 14        Afghanistan  2014                                89.500000
# 755          Colombia  2020                               100.000000
#
#       Access to clean fuels for cooking  \
# 1406                                1.6
# 3598                               60.0
# ...

# %%
sampled_df.isnull().sum()
# Out:
# Entity                                                                0
# Year                                                                  0
# Access to electricity (% of population)                               0
# Access to clean fuels for cooking                                    22
# Renewable-electricity-generating-capacity-per-capita                135
# Financial flows to developing countries (US $)                      287
# Renewable energy share in the total final energy consumption (%)     24
# Electricity from fossil fuels (TWh)                                   3
# Electricity from nuclear (TWh)                                       16
# Electricity from renewables (TWh)                                     3
# Low-carbon electricity (% electricity)                                9
# Primary energy consumption per capita (kWh/person)                    0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          24
# ...

# %%
sampled_df.to_csv("database\\test_sample.csv")
